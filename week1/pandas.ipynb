# %%
import pandas as pd

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("hassanjameelahmed/house-prices-advanced-regression-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: /Users/nirmal/.cache/kagglehub/datasets/hassanjameelahmed/house-prices-advanced-regression-dataset/versions/1

# %%
#read csv file into a dataframe
df=pd.read_csv('data.csv')

# %%
df.head() #view first 5 rows
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0      NaN   Pave   NaN      Reg
# 1   2          20       RL         80.0   9600.0   Pave   NaN      Reg
# 2   2          20       RL         80.0   9600.0   Pave   NaN      Reg
# 3   3          60       RL         68.0  11250.0   Pave   NaN      IR1
# 4   4          70       RL         60.0   9550.0   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.head(10) #view first 10 rows
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0      NaN   Pave   NaN      Reg
# 1   2          20       RL         80.0   9600.0   Pave   NaN      Reg
# 2   2          20       RL         80.0   9600.0   Pave   NaN      Reg
# 3   3          60       RL         68.0  11250.0   Pave   NaN      IR1
# 4   4          70       RL         60.0   9550.0   Pave   NaN      IR1
# 5   5          60       RL         84.0  14260.0   Pave   NaN      IR1
# 6   6          50       RL         85.0  14115.0   Pave   NaN      IR1
# 7   7          20       RL         75.0  10084.0   Pave   NaN      Reg
# 8   8          60       RL          NaN  10382.0   Pave   NaN      IR1
# 9   9          50       RM         51.0   6120.0   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
df.tail(7) #view last 7 rows
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1454  1454          20       RL         90.0  17217.0   Pave   NaN      Reg
# 1455  1455          20       FV         62.0   7500.0   Pave  Pave      Reg
# 1456  1456          60       RL         62.0   7917.0   Pave   NaN      Reg
# 1457  1457          20       RL         85.0  13175.0   Pave   NaN      Reg
# 1458  1458          70       RL         66.0   9042.0   Pave   NaN      Reg
# 1459  1459          20       RL         68.0   9717.0   Pave   NaN      Reg
# 1460  1460          20       RL         75.0   9937.0   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1454         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
df.info() #summary of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1461 non-null   int64
#  1   MSSubClass     1461 non-null   int64
#  2   MSZoning       1461 non-null   object
#  3   LotFrontage    1202 non-null   float64
#  4   LotArea        1460 non-null   float64
#  5   Street         1461 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1461 non-null   object
#  8   LandContour    1461 non-null   object
#  9   Utilities      1461 non-null   object
#  10  LotConfig      1461 non-null   object
#  11  LandSlope      1461 non-null   object
#  12  Neighborhood   1461 non-null   object
#  13  Condition1     1461 non-null   object
#  14  Condition2     1461 non-null   object
#  15  BldgType       1461 non-null   object
#  16  HouseStyle     1461 non-null   object
# ...

# %%
df.describe() #get statistical summary of numerical columns
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1461.000000  1461.000000  1202.000000    1460.000000  1461.000000
# mean    730.001369    56.872005    70.058236   10517.615753     6.099247
# std     421.896318    42.297099    24.276336    9981.147092     1.382525
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.000000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.000000    50.000000    69.500000    9485.000000     6.000000
# 75%    1095.000000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1461.000000  1461.000000   1461.000000  1453.000000  1461.000000  ...
# mean      5.577002  1971.271047   1984.859685   103.613902   444.005476  ...
# std       1.114225    30.192813     20.639639   181.024283   456.156144  ...
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df2=df[['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
       'Alley', 'LotShape', 'LandContour', 'Utilities','SalePrice']] #create new dataframe with selected columns

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           1461 non-null   int64
#  1   MSSubClass   1461 non-null   int64
#  2   MSZoning     1461 non-null   object
#  3   LotFrontage  1202 non-null   float64
#  4   LotArea      1460 non-null   float64
#  5   Street       1461 non-null   object
#  6   Alley        91 non-null     object
#  7   LotShape     1461 non-null   object
#  8   LandContour  1461 non-null   object
#  9   Utilities    1461 non-null   object
#  10  SalePrice    1461 non-null   int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 125.7+ KB

# %%
df3=df2.drop(columns=['LandContour']) #remove 'LandContour' column using drop
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           1461 non-null   int64
#  1   MSSubClass   1461 non-null   int64
#  2   MSZoning     1461 non-null   object
#  3   LotFrontage  1202 non-null   float64
#  4   LotArea      1460 non-null   float64
#  5   Street       1461 non-null   object
#  6   Alley        91 non-null     object
#  7   LotShape     1461 non-null   object
#  8   Utilities    1461 non-null   object
#  9   SalePrice    1461 non-null   int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 114.3+ KB

# %%
df3.drop(columns=['Alley'], inplace=True) #remove 'LandContour' column using drop
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           1461 non-null   int64
#  1   MSSubClass   1461 non-null   int64
#  2   MSZoning     1461 non-null   object
#  3   LotFrontage  1202 non-null   float64
#  4   LotArea      1460 non-null   float64
#  5   Street       1461 non-null   object
#  6   LotShape     1461 non-null   object
#  7   Utilities    1461 non-null   object
#  8   SalePrice    1461 non-null   int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 102.9+ KB

# %%
street_col=df['Street'] #access 'Street' column
street_col
# Out:
# 0       Pave
# 1       Pave
# 2       Pave
# 3       Pave
# 4       Pave
#         ...
# 1456    Pave
# 1457    Pave
# 1458    Pave
# 1459    Pave
# 1460    Pave
# Name: Street, Length: 1461, dtype: object

# %%
df3
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0      NaN   Pave      Reg
# 1        2          20       RL         80.0   9600.0   Pave      Reg
# 2        2          20       RL         80.0   9600.0   Pave      Reg
# 3        3          60       RL         68.0  11250.0   Pave      IR1
# 4        4          70       RL         60.0   9550.0   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1456  1456          60       RL         62.0   7917.0   Pave      Reg
# 1457  1457          20       RL         85.0  13175.0   Pave      Reg
# 1458  1458          70       RL         66.0   9042.0   Pave      Reg
# 1459  1459          20       RL         68.0   9717.0   Pave      Reg
# 1460  1460          20       RL         75.0   9937.0   Pave      Reg
#
#      Utilities  SalePrice
# 0       AllPub     208500
# 1       AllPub     181500
# 2       AllPub     181500
# ...

# %%
#ectract row
row=df.iloc[1455] #get 5th row
row
# Out:
# Id                 1455
# MSSubClass           20
# MSZoning             FV
# LotFrontage        62.0
# LotArea          7500.0
#                   ...
# MoSold               10
# YrSold             2009
# SaleType             WD
# SaleCondition    Normal
# SalePrice        185000
# Name: 1455, Length: 81, dtype: object

# %%
#extract specific cell
cell=df.at[2,'LotArea'] #get cell at row index 1455 and column 'LotArea'
cell
# Out:
# np.float64(9600.0)

# %%
#filter rows based on condition

filtered_df=df3[df3['LotArea']>10000] #get rows where 'LotArea' > 10000
filtered_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 3        3          60       RL         68.0  11250.0   Pave      IR1
# 5        5          60       RL         84.0  14260.0   Pave      IR1
# 6        6          50       RL         85.0  14115.0   Pave      IR1
# 7        7          20       RL         75.0  10084.0   Pave      Reg
# 8        8          60       RL          NaN  10382.0   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1443  1443          60       FV         85.0  11003.0   Pave      Reg
# 1447  1447          20       RL          NaN  26142.0   Pave      IR1
# 1449  1449          50       RL         70.0  11767.0   Pave      Reg
# 1454  1454          20       RL         90.0  17217.0   Pave      Reg
# 1457  1457          20       RL         85.0  13175.0   Pave      Reg
#
#      Utilities  SalePrice
# 3       AllPub     223500
# 5       AllPub     250000
# 6       AllPub     143000
# ...

# %%
filtered_df2=df3[(df3['LotArea']>10000) & (df3['LotFrontage'] > 90)]  #get rows where 'LotArea' > 10000 and 'LotFrontage' > 70
filtered_df2
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 14      14          20       RL         91.0  10652.0   Pave      IR1
# 21      21          60       RL        101.0  14215.0   Pave      IR1
# 26      26          20       RL        110.0  14230.0   Pave      Reg
# 28      28          20       RL         98.0  11478.0   Pave      Reg
# 36      36          60       RL        108.0  13418.0   Pave      Reg
# ...    ...         ...      ...          ...      ...    ...      ...
# 1356  1356          80       RL        102.0  10192.0   Pave      IR1
# 1360  1360          20       RL        129.0  16737.0   Pave      Reg
# 1362  1362          20       RL        124.0  16158.0   Pave      IR1
# 1434  1434          60       RL         93.0  10261.0   Pave      IR1
# 1438  1438          20       RL         96.0  12444.0   Pave      Reg
#
#      Utilities  SalePrice
# 14      AllPub     279500
# 21      AllPub     325300
# 26      AllPub     256300
# ...

# %%
result=df3.query('LotArea > 10000 and LotFrontage > 90')  #using query method to filter rows
result
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 14      14          20       RL         91.0  10652.0   Pave      IR1
# 21      21          60       RL        101.0  14215.0   Pave      IR1
# 26      26          20       RL        110.0  14230.0   Pave      Reg
# 28      28          20       RL         98.0  11478.0   Pave      Reg
# 36      36          60       RL        108.0  13418.0   Pave      Reg
# ...    ...         ...      ...          ...      ...    ...      ...
# 1356  1356          80       RL        102.0  10192.0   Pave      IR1
# 1360  1360          20       RL        129.0  16737.0   Pave      Reg
# 1362  1362          20       RL        124.0  16158.0   Pave      IR1
# 1434  1434          60       RL         93.0  10261.0   Pave      IR1
# 1438  1438          20       RL         96.0  12444.0   Pave      Reg
#
#      Utilities  SalePrice
# 14      AllPub     279500
# 21      AllPub     325300
# 26      AllPub     256300
# ...

# %%
df3.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape Utilities  \
# 0   1          60       RL         65.0      NaN   Pave      Reg    AllPub
# 1   2          20       RL         80.0   9600.0   Pave      Reg    AllPub
# 2   2          20       RL         80.0   9600.0   Pave      Reg    AllPub
# 3   3          60       RL         68.0  11250.0   Pave      IR1    AllPub
# 4   4          70       RL         60.0   9550.0   Pave      IR1    AllPub
#
#    SalePrice
# 0     208500
# 1     181500
# 2     181500
# 3     223500
# 4     140000

# %%
df3.isna().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage    259
# LotArea          1
# Street           0
# LotShape         0
# Utilities        0
# SalePrice        0
# dtype: int64

# %%
df3.dropna(inplace=True)  #remove rows with missing values
df3.isna().sum()
# Out:
# Id             0
# MSSubClass     0
# MSZoning       0
# LotFrontage    0
# LotArea        0
# Street         0
# LotShape       0
# Utilities      0
# SalePrice      0
# dtype: int64

# %%
# df.fillna(0, inplace=True)  #fill missing values with 0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1201 entries, 1 to 1460
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           1201 non-null   int64
#  1   MSSubClass   1201 non-null   int64
#  2   MSZoning     1201 non-null   object
#  3   LotFrontage  1201 non-null   float64
#  4   LotArea      1201 non-null   float64
#  5   Street       1201 non-null   object
#  6   LotShape     1201 non-null   object
#  7   Utilities    1201 non-null   object
#  8   SalePrice    1201 non-null   int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 93.8+ KB

# %%
df3.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape Utilities  \
# 1   2          20       RL         80.0   9600.0   Pave      Reg    AllPub
# 2   2          20       RL         80.0   9600.0   Pave      Reg    AllPub
# 3   3          60       RL         68.0  11250.0   Pave      IR1    AllPub
# 4   4          70       RL         60.0   9550.0   Pave      IR1    AllPub
# 5   5          60       RL         84.0  14260.0   Pave      IR1    AllPub
#
#    SalePrice
# 1     181500
# 2     181500
# 3     223500
# 4     140000
# 5     250000

# %%
#check duplicates
df3.duplicated().sum()
# Out:
# np.int64(1)

# %%
#remove duplicates
df3.drop_duplicates(inplace=True)

df3.duplicated().sum()
# Out:
# np.int64(0)

# %%
df3.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape Utilities  \
# 1   2          20       RL         80.0   9600.0   Pave      Reg    AllPub
# 3   3          60       RL         68.0  11250.0   Pave      IR1    AllPub
# 4   4          70       RL         60.0   9550.0   Pave      IR1    AllPub
# 5   5          60       RL         84.0  14260.0   Pave      IR1    AllPub
# 6   6          50       RL         85.0  14115.0   Pave      IR1    AllPub
#
#    SalePrice
# 1     181500
# 3     223500
# 4     140000
# 5     250000
# 6     143000

# %%
#identify outliers
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
sns.boxplot(x=df3['SalePrice'])
plt.title('Boxplot of SalePrice')
plt.show()

# %%
df4=df3.query('SalePrice < 350000')  #remove outliers where 'SalePrice' > 350000
df4
plt.figure(figsize=(10,5))
sns.boxplot(x=df4['SalePrice'])
plt.title('Boxplot of SalePrice after removing outliers')
plt.show()

# %%
#Feature Engineering
df4['NewCol']=df4['LotArea'] / df4['LotFrontage']  #create new column as ratio of 'LotArea' and 'LotFrontage'
df4.head()
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_49984/1014646867.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['NewCol']=df4['LotArea'] / df4['LotFrontage']  #create new column as ratio of 'LotArea' and 'LotFrontage'
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape Utilities  \
# 1   2          20       RL         80.0   9600.0   Pave      Reg    AllPub
# 3   3          60       RL         68.0  11250.0   Pave      IR1    AllPub
# 4   4          70       RL         60.0   9550.0   Pave      IR1    AllPub
# 5   5          60       RL         84.0  14260.0   Pave      IR1    AllPub
# 6   6          50       RL         85.0  14115.0   Pave      IR1    AllPub
#
#    SalePrice      NewCol
# ...

# %%
df4['LotShape'].unique()
# Out:
# array(['Reg', 'IR1', 'IR2', 'IR3'], dtype=object)

# %%
df4['LotShape'].value_counts()
# Out:
# LotShape
# Reg    828
# IR1    293
# IR2     20
# IR3      6
# Name: count, dtype: int64

# %%
#visualise pie chart sns
plt.figure(figsize=(8,8))
plt.pie(df4['LotShape'].value_counts(), labels=df4['LotShape'].value_counts().index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of LotShape')
plt.show()

# %%
df['LotShape']
# Out:
# 0       Reg
# 1       Reg
# 2       Reg
# 3       IR1
# 4       IR1
#        ...
# 1456    Reg
# 1457    Reg
# 1458    Reg
# 1459    Reg
# 1460    Reg
# Name: LotShape, Length: 1461, dtype: object

# %%
#encode categorical column
from sklearn.preprocessing import LabelEncoder

lotShape_encoder = LabelEncoder()
df4['LotShape_Encoded'] = lotShape_encoder.fit_transform(df4['LotShape'])
df4.head(20)
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_49984/1120922061.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['LotShape_Encoded'] = lotShape_encoder.fit_transform(df4['LotShape'])
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape Utilities  \
# 1    2          20       RL         80.0   9600.0   Pave      Reg    AllPub
# 3    3          60       RL         68.0  11250.0   Pave      IR1    AllPub
# 4    4          70       RL         60.0   9550.0   Pave      IR1    AllPub
# 5    5          60       RL         84.0  14260.0   Pave      IR1    AllPub
# 6    6          50       RL         85.0  14115.0   Pave      IR1    AllPub
# ...

# %%
mszoning_encoder = LabelEncoder()
df4['MSZoning_Encoded'] = mszoning_encoder.fit_transform(df4['MSZoning'])
df4.head(5)
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_49984/1878060289.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['MSZoning_Encoded'] = mszoning_encoder.fit_transform(df4['MSZoning'])
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape Utilities  \
# 1   2          20       RL         80.0   9600.0   Pave      Reg    AllPub
# 3   3          60       RL         68.0  11250.0   Pave      IR1    AllPub
# 4   4          70       RL         60.0   9550.0   Pave      IR1    AllPub
# 5   5          60       RL         84.0  14260.0   Pave      IR1    AllPub
# 6   6          50       RL         85.0  14115.0   Pave      IR1    AllPub
#
#    SalePrice      NewCol  LotShape_Encoded  MSZoning_Encoded
# ...

# %%
#Normalization and Scaling
from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = MinMaxScaler()
df4[['LotArea_scaled']] = scaler.fit_transform(df4[['LotArea']])
df4.head(5)
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_49984/1645739598.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4[['LotArea_scaled']] = scaler.fit_transform(df4[['LotArea']])
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape Utilities  \
# 1   2          20       RL         80.0   9600.0   Pave      Reg    AllPub
# 3   3          60       RL         68.0  11250.0   Pave      IR1    AllPub
# 4   4          70       RL         60.0   9550.0   Pave      IR1    AllPub
# 5   5          60       RL         84.0  14260.0   Pave      IR1    AllPub
# 6   6          50       RL         85.0  14115.0   Pave      IR1    AllPub
#
#    SalePrice      NewCol  LotShape_Encoded  MSZoning_Encoded  LotArea_scaled
# ...

# %%
df5=df4.drop(columns=['LotShape', 'MSZoning'])
df5.reset_index(drop=True, inplace=True)
df5.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea Street Utilities  SalePrice  \
# 0   2          20         80.0   9600.0   Pave    AllPub     181500
# 1   3          60         68.0  11250.0   Pave    AllPub     223500
# 2   4          70         60.0   9550.0   Pave    AllPub     140000
# 3   5          60         84.0  14260.0   Pave    AllPub     250000
# 4   6          50         85.0  14115.0   Pave    AllPub     143000
#
#        NewCol  LotShape_Encoded  MSZoning_Encoded  LotArea_scaled
# 0  120.000000                 3                 3        0.119492
# 1  165.441176                 0                 3        0.143246
# 2  159.166667                 0                 3        0.118772
# 3  169.761905                 0                 3        0.186580
# 4  166.058824                 0                 3        0.184492
